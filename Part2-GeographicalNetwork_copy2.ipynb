# %%
import math
import json
import numpy as np
import pandas as pd
import networkx as nx
#import cartopy.crs as ccrs
import matplotlib.pyplot as plt
from IPython.display import Image
# %matplotlib inline
import os
import conda

conda_file_dir = conda.__file__
conda_dir = conda_file_dir.split('lib')[0]
proj_lib = os.path.join(os.path.join(conda_dir, 'share'), 'proj')
os.environ["PROJ_LIB"] = proj_lib

from mpl_toolkits.basemap import Basemap

# %%
cities = pd.read_csv('data/Top50/top50cities.csv',delimiter=',')

# %%
#import nodes to get id from nodes/hosts
hosts = pd.DataFrame() #creates a new dataframe that's empty
for idx,city in cities.iterrows():#.loc[cities['2017']>50000].iterrows():
    for p in range(1,14):
        if (os.path.exists('data/Top50/hosts/'+city['name']+str(p)+'.csv')):
            df = pd.read_csv('data/Top50/hosts/'+city['name']+str(p)+'.csv',index_col=False)
            hosts = pd.concat([hosts,df]).reset_index(drop=True)
print(len(hosts))
hosts=hosts.drop_duplicates()
print(len(hosts))
# Out:
# 10586
# 10582

# %%
rev = pd.DataFrame() #creates a new dataframe that's empty
for idx,city in cities.iterrows():#.loc[cities['2017']>50000].iterrows():
    if os.path.exists('data/Top50/reviews/'+city['name']+'Rev.csv'):
        df = pd.read_csv('data/Top50/reviews/'+city['name']+'Rev.csv',index_col=False)
        rev = pd.concat([rev,df]).reset_index(drop=True)
print(len(rev))
rev=rev.drop_duplicates()
print(len(rev))
# Out:
# 96090
# 96085

# %%
# !pip install geopy
from geopy import geocoders
# Out:
# Requirement already satisfied: geopy in /Users/Eike/anaconda3/lib/python3.6/site-packages (1.17.0)
# Requirement already satisfied: geographiclib<2,>=1.49 in /Users/Eike/anaconda3/lib/python3.6/site-packages (from geopy) (1.49)

# %%
cities_not_found = []
def getCityCoords(name):
    # if geopy does not work -> http://www.geonames.org/login and log in with cred:
    # username: kacper
    # pass : zaq12345
    gn = geocoders.GeoNames(username='kacper')
    try:
        loc = gn.geocode(name, timeout=10)
        
        if loc is None:
            try: 
                loc =gn.geocode(name.split(',')[0],timeout=10)
                if loc is None:
                    raise TypeError
            except Exception as inst:
                print('This city was not found:',name)
                return None
    except Exception as inst:
        print('This city was not found:',name)
        cities_not_found.append(name)
        return None
    #print(len(loc))
   # print(loc[0].raw)
    return loc

# %%
#loc
#loc = getCityCoords(name)
#rev['lat']='NaN'
#rev['lng']='NaN'
allCities=rev.fromPublicAddressDescription.unique()
for city in allCities.tolist():
    loc2=getCityCoords(city)
    if loc2:
        rev.loc[rev.fromPublicAddressDescription==city]['lat']=loc2.raw['lat']
        rev.loc[rev.fromPublicAddressDescription==city]['lng']=loc2.raw['lng']






#for idx,row in rev.iterrows():
#    if row['lat']=='NaN':
#        print(idx)
#        #print(row['fromPublicAddressDescription'])
#        loc2=getCityCoords(row['fromPublicAddressDescription'])
#        if loc2:
#            #print(loc.raw['lat'],loc.raw['lng'])
#            rev['lat'][idx]=loc2.raw['lat']
#            rev['lng'][idx]=loc2.raw['lng']

        #rev.loc[idx]['lng']
# Out:
# 182
# This city was not found: Bilhorod-Dnistrovs'kyi, Odessa Oblast, Ukraine
# 197
# This city was not found: Bilhorod-Dnistrovs'kyi, Odessa Oblast, Ukraine
# 207
# This city was not found: Yenakijeve, Donetsk Oblast, Ukraine
# 580
# This city was not found: guayaqil, Ecuador
# 977
# This city was not found: La boulladisse, Provance Alpes, France
# 1173
# This city was not found: Pervomais'k, Mykolaivs'ka oblast, Ukraine
# 1351
# This city was not found: khajurajo, Madhya Pradesh, India
# 1645
# This city was not found: Volgogard, Volgograd Oblast, Russian Federation
# 2246
# This city was not found: i was born in, Italy
# 2253
# This city was not found: Plyos, Ivanovo Oblast. Привллжский район,, Russian Federation
# 2306
# /Users/Eike/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   del sys.path[0]
# /Users/Eike/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# 2307
# This city was not found: Ski, Akershus, Norway
# 2308
# This city was not found: Reykjavík, Iceland
# 2309
# This city was not found: Mosfell, South, Iceland
# 2310
# This city was not found: Oslo, Oslo, Norway
# 2311
# This city was not found: Berlin, Berlin, Germany
# 2312
# This city was not found: Baku, Baku, Azerbaijan
# 2313
# This city was not found: Fribourg, Fribourg, Switzerland
# 2314
# This city was not found: Gdynia, Pomeranian Voivodeship, Poland
# 2315
# This city was not found: Chongqing, Chongqing, China
# 2316
# This city was not found: saida, south, Lebanon
# 2317
# This city was not found: Saint Petersburg, Russian Federation
# 2318
# This city was not found: Tehran, Tehran, Iran (Islamic Republic of)
# 2319
# This city was not found: Tehran, Tehran, Iran
# 2320
# 2321
# 2322
# 2323
# 2324
# 2325
# 2326
# 2327
# 2328
# 2329
# 2330
# 2331
# 2332
# 2333
# 2334
# 2335
# 2336
# 2337
# 2338
# 2339
# 2340
# 2341
# 2342
# 2343
# 2344
# 2345
# 2346
# 2347
# 2348
# 2349
# 2350
# 2351
# 2352
# 2353
# 2354
# 2355
# 2356
# 2357
# 2358
# 2359
# 2360
# 2361
# 2362
# 2363
# 2364
# 2365
# 2366
# 2367
# 2368
# 2369
# 2370
# 2371
# 2372
# 2373
# 2374
# 2375
# 2376
# 2377
# 2378
# 2379
# 2380
# 2381
# 2382
# 2383
# 2384
# 2385
# 2386
# 2387
# 2388
# 2389
# 2390
# 2391
# 2392
# 2393
# 2394
# 2395
# 2396
# 2397
# 2398
# 2399
# 2400
# 2401
# 2402
# 2403
# 2404
# 2405
# 2406
# 2407
# 2408
# 2409
# 2410
# 2411
# 2412
# 2413
# 2414
# 2415
# 2416
# 2417
# 2418
# 2419
# 2420
# 2421
# 2422
# 2423
# 2424
# 2425
# 2426
# 2427
# 2428
# 2429
# 2430
# 2431
# 2432
# 2433
# 2434
# 2435
# 2436
# 2437
# 2438
# 2439
# 2440
# 2441
# 2442
# 2443
# 2444
# 2445
# 2446
# 2447
# 2448
# 2449
# 2450
# 2451
# 2452
# 2453
# 2454
# 2455
# 2456
# 2457
# 2458
# 2459
# 2460
# 2461
# 2462
# 2463
# 2464
# 2465
# 2466
# This city was not found: ChIJq5EYs65unUcRC-cFw9pQGh4
# 2467
# 2468
# 2469
# 2470
# 2471
# 2472
# 2473
# 2474
# 2475
# 2476
# 2477
# 2478
# 2479
# 2480
# 2481
# 2482
# 2483
# 2484
# 2485
# 2486
# 2487
# 2488
# 2489
# 2490
# 2491
# 2492
# 2493
# 2494
# 2495
# 2496
# 2497
# 2498
# 2499
# 2500
# 2501
# 2502
# 2503
# 2504
# 2505
# 2506
# 2507
# 2508
# 2509
# 2510
# 2511
# 2512
# 2513
# 2514
# This city was not found: Guishan dist, Taoyuan, Taiwan, Province of China
# 2515
# 2516
# 2517
# 2518
# 2519
# 2520
# 2521
# 2522
# 2523
# 2524
# 2525
# 2526
# 2527
# 2528
# 2529
# 2530
# 2531
# 2532
# 2533
# 2534
# 2535
# 2536
# 2537
# 2538
# 2539
# 2540
# 2541
# 2542
# 2543
# 2544
# 2545
# 2546
# 2547
# 2548
# 2549
# 2550
# 2551
# 2552
# 2553
# 2554
# 2555
# 2556
# 2557
# 2558
# 2559
# 2560
# 2561
# 2562
# 2563
# 2564
# 2565
# 2566
# 2567
# 2568
# 2569
# 2570
# 2571
# 2572
# 2573
# 2574
# 2575
# 2576
# 2577
# 2578
# 2579
# 2580
# 2581
# 2582
# 2583
# 2584
# 2585
# 2586
# 2587
# 2588
# 2589
# 2590
# 2591
# 2592
# 2593
# 2594
# 2595
# 2596
# 2597
# 2598
# 2599
# 2600
# 2601
# 2602
# 2603
# 2604
# 2605
# 2606
# 2607
# 2608
# 2609
# 2610
# 2611
# 2612
# 2613
# 2614
# 2615
# 2616
# 2617
# 2618
# 2619
# 2620
# 2621
# 2622
# This city was not found: Khmel'nyts'kyi, Khmel'nyts'ka oblast, Ukraine
# 2623
# 2624
# 2625
# 2626
# 2627
# 2628
# 2629
# 2630
# 2631
# 2632
# 2633
# 2634
# 2635
# 2636
# 2637
# 2638
# 2639
# 2640
# 2641
# 2642
# 2643
# 2644
# 2645
# 2646
# 2647
# 2648
# 2649
# 2650
# 2651
# 2652
# 2653
# 2654
# 2655
# 2656
# 2657
# 2658
# 2659
# 2660
# 2661
# 2662
# 2663
# 2664
# 2665
# 2666
# 2667
# 2668
# 2669
# 2670
# 2671
# 2672
# 2673
# 2674
# 2675
# 2676
# 2677
# 2678
# 2679
# 2680
# 2681
# 2682
# 2683
# 2684
# 2685
# 2686
# 2687
# 2688
# 2689
# 2690
# 2691
# 2692
# 2693
# 2694
# 2695
# 2696
# 2697
# 2698
# 2699
# 2700
# 2701
# 2702
# 2703
# 2704
# 2705
# 2706
# 2707
# 2708
# 2709
# 2710
# 2711
# 2712
# 2713
# 2714
# 2715
# 2716
# 2717
# 2718
# 2719
# 2720
# 2721
# 2722
# 2723
# 2724
# 2725
# 2726
# 2727
# 2728
# 2729
# 2730
# 2731
# 2732
# 2733
# 2734
# 2735
# 2736
# 2737
# 2738
# 2739
# 2740
# 2741
# 2742
# 2743
# 2744
# 2745
# 2746
# 2747
# 2748
# 2749
# 2750
# 2751
# 2752
# 2753
# 2754
# 2755
# 2756
# 2757
# 2758
# 2759
# 2760
# 2761
# 2762
# 2763
# 2764
# 2765
# 2766
# 2767
# 2768
# 2769
# 2770
# 2771
# 2772
# 2773
# 2774
# 2775
# 2776
# 2777
# 2778
# 2779
# 2780
# 2781
# 2782
# 2783
# 2784
# 2785
# 2786
# 2787
# 2788
# 2789
# 2790
# 2791
# 2792
# 2793
# 2794
# 2795
# 2796
# 2797
# 2798
# 2799
# 2800
# 2801
# 2802
# 2803
# 2804
# 2805
# 2806
# 2807
# 2808
# 2809
# 2810
# 2811
# 2812
# 2813
# 2814
# 2815
# 2816
# 2817
# 2818
# 2819
# 2820
# 2821
# 2822
# 2823
# 2824
# 2825
# 2826
# 2827
# 2828
# 2829
# 2830
# 2831
# 2832
# 2833
# This city was not found: Olmalik, Uzbekistan
# 2834
# 2835
# 2836
# 2837
# 2838
# 2839
# 2840
# 2841
# 2842
# 2843
# 2844
# 2845
# 2846
# 2847
# 2848
# 2849
# 2850
# 2851
# 2852
# 2853
# 2854
# 2855
# 2856
# 2857
# 2858
# 2859
# 2860
# 2861
# 2862
# 2863
# 2864
# 2865
# 2866
# 2867
# 2868
# 2869
# 2870
# 2871
# 2872
# 2873
# 2874
# 2875
# 2876
# 2877
# 2878
# 2879
# 2880
# 2881
# 2882
# 2883
# 2884
# 2885
# 2886
# 2887
# 2888
# 2889
# 2890
# 2891
# 2892
# 2893
# 2894
# 2895
# 2896
# 2897
# 2898
# 2899
# 2900
# 2901
# 2902
# 2903
# 2904
# 2905
# 2906
# 2907
# 2908
# 2909
# 2910
# 2911
# 2912
# 2913
# 2914
# 2915
# 2916
# 2917
# 2918
# 2919
# 2920
# 2921
# 2922
# 2923
# 2924
# 2925
# 2926
# 2927
# 2928
# 2929
# 2930
# 2931
# 2932
# 2933
# 2934
# 2935
# 2936
# 2937
# 2938
# 2939
# 2940
# 2941
# 2942
# 2943
# 2944
# 2945
# 2946
# 2947
# 2948
# 2949
# 2950
# 2951
# 2952
# 2953
# 2954
# 2955
# 2956
# 2957
# 2958
# 2959
# 2960
# 2961
# 2962
# 2963
# 2964
# 2965
# 2966
# 2967
# 2968
# 2969
# 2970
# 2971
# 2972
# 2973
# 2974
# 2975
# 2976
# 2977
# 2978
# 2979
# 2980
# 2981
# 2982
# 2983
# This city was not found: Guishan dist, Taoyuan, Taiwan, Province of China
# 2984
# 2985
# 2986
# 2987
# 2988
# 2989
# 2990
# 2991
# 2992
# 2993
# 2994
# 2995
# 2996
# 2997
# 2998
# 2999
# 3000
# 3001
# 3002
# 3003
# 3004
# 3005
# 3006
# 3007
# 3008
# 3009
# 3010
# 3011
# 3012
# 3013
# 3014
# 3015
# 3016
# 3017
# 3018
# 3019
# 3020
# 3021
# 3022
# 3023
# 3024
# 3025
# 3026
# 3027
# 3028
# 3029
# 3030
# 3031
# 3032
# 3033
# 3034
# 3035
# 3036
# 3037
# 3038
# 3039
# 3040
# 3041
# 3042
# 3043
# 3044
# 3045
# 3046
# 3047
# 3048
# 3049
# 3050
# 3051
# 3052
# 3053
# 3054
# 3055
# 3056
# 3057
# 3058
# 3059
# 3060
# 3061
# 3062
# 3063
# 3064
# 3065
# 3066
# 3067
# 3068
# 3069
# 3070
# 3071
# 3072
# 3073
# 3074
# 3075
# 3076
# 3077
# 3078
# 3079
# 3080
# 3081
# 3082
# 3083
# 3084
# 3085
# 3086
# 3087
# 3088
# 3089
# 3090
# 3091
# 3092
# 3093
# 3094
# 3095
# 3096
# 3097
# 3098
# 3099
# 3100
# 3101
# 3102
# 3103
# 3104
# 3105
# 3106
# 3107
# 3108
# 3109
# 3110
# 3111
# 3112
# 3113
# 3114
# 3115
# 3116
# 3117
# 3118
# 3119
# 3120
# 3121
# 3122
# 3123
# 3124
# 3125
# 3126
# 3127
# 3128
# 3129
# 3130
# 3131
# 3132
# 3133
# 3134
# 3135
# 3136
# 3137
# 3138
# 3139
# 3140
# 3141
# 3142
# 3143
# 3144
# 3145
# 3146
# 3147
# 3148
# 3149
# 3150
# 3151
# 3152
# 3153
# 3154
# 3155
# 3156
# 3157
# 3158
# 3159
# 3160
# 3161
# 3162
# 3163
# 3164
# 3165
# 3166
# 3167
# 3168
# 3169
# 3170
# 3171
# 3172
# 3173
# 3174
# 3175
# 3176
# 3177
# 3178
# 3179
# 3180
# 3181
# 3182
# 3183
# 3184
# 3185
# 3186
# 3187
# 3188
# 3189
# 3190
# 3191
# 3192
# 3193
# 3194
# 3195
# 3196
# 3197
# 3198
# 3199
# 3200
# 3201
# 3202
# 3203
# 3204
# 3205
# 3206
# 3207
# 3208
# 3209
# 3210
# 3211
# 3212
# 3213
# 3214
# 3215
# 3216
# 3217
# 3218
# 3219
# 3220
# 3221
# 3222
# 3223
# 3224
# 3225
# 3226
# 3227
# 3228
# 3229
# 3230
# 3231
# 3232
# 3233
# 3234
# 3235
# 3236
# 3237
# 3238
# 3239
# 3240
# 3241
# 3242
# 3243
# 3244
# 3245
# 3246
# 3247
# 3248
# 3249
# 3250
# 3251
# 3252
# 3253
# 3254
# 3255
# 3256
# 3257
# 3258
# 3259
# 3260
# 3261
# 3262
# 3263
# 3264
# 3265
# 3266
# 3267
# 3268
# 3269
# 3270
# 3271
# 3272
# 3273
# 3274
# 3275
# 3276
# 3277
# 3278
# 3279
# 3280
# 3281
# 3282
# 3283
# 3284
# 3285
# 3286
# 3287
# 3288
# 3289
# 3290
# 3291
# 3292
# 3293
# 3294
# 3295
# 3296
# 3297
# 3298
# 3299
# 3300
# 3301
# 3302
# 3303
# 3304
# 3305
# 3306
# 3307
# 3308
# 3309
# 3310
# 3311
# 3312
# 3313
# 3314
# 3315
# 3316
# 3317
# 3318
# 3319
# 3320
# 3321
# 3322
# 3323
# 3324
# 3325
# 3326
# 3327
# 3328
# 3329
# 3330
# 3331
# 3332
# 3333
# 3334
# 3335
# 3336
# 3337
# 3338
# 3339
# 3340
# 3341
# 3342
# 3343
# 3344
# 3345
# This city was not found: Clovis (Yosemite), CA, USA
# 3346
# 3347
# 3348
# 3349
# 3350
# 3351
# 3352
# 3353
# 3354
# 3355
# 3356
# 3357
# 3358
# 3359
# 3360
# 3361
# 3362
# 3363
# 3364
# 3365
# 3366
# 3367
# 3368
# 3369
# 3370
# 3371
# 3372
# 3373
# 3374
# 3375
# 3376
# 3377
# 3378
# 3379
# 3380
# 3381
# 3382
# 3383
# 3384
# 3385
# 3386
# 3387
# 3388
# 3389
# 3390
# 3391
# 3392
# 3393
# 3394
# 3395
# 3396
# 3397
# 3398
# 3399
# 3400
# 3401
# 3402
# 3403
# 3404
# 3405
# 3406
# 3407
# 3408
# 3409
# 3410
# 3411
# 3412
# 3413
# 3414
# 3415
# 3416
# 3417
# 3418
# 3419
# 3420
# 3421
# 3422
# 3423
# 3424
# 3425
# This city was not found: Rēzekne Municipality, Latvia
# 3426
# 3427
# 3428
# 3429
# 3430
# 3431
# 3432
# 3433
# 3434
# 3435
# 3436
# 3437
# 3438
# 3439
# 3440
# 3441
# 3442
# 3443
# 3444
# 3445
# 3446
# 3447
# 3448
# 3449
# 3450
# 3451
# 3452
# 3453
# 3454
# 3455
# 3456
# 3457
# 3458
# 3459
# 3460
# 3461
# 3462
# 3463
# 3464
# 3465
# 3466
# 3467
# 3468
# 3469
# 3470
# 3471
# 3472
# 3473
# 3474
# 3475
# 3476
# 3477
# 3478
# 3479
# 3480
# 3481
# 3482
# 3483
# 3484
# 3485
# 3486
# 3487
# 3488
# 3489
# 3490
# 3491
# 3492
# 3493
# 3494
# 3495
# 3496
# 3497
# 3498
# 3499
# 3500
# 3501
# 3502
# 3503
# 3504
# 3505
# 3506
# 3507
# 3508
# 3509
# 3510
# 3511
# 3512
# 3513
# 3514
# 3515
# 3516
# 3517
# 3518
# 3519
# 3520
# 3521
# 3522
# 3523
# 3524
# 3525
# 3526
# 3527
# 3528
# 3529
# 3530
# 3531
# 3532
# 3533
# 3534
# 3535
# 3536
# 3537
# 3538
# 3539
# 3540
# 3541
# 3542
# 3543
# 3544
# 3545
# 3546
# 3547
# 3548
# 3549
# 3550
# 3551
# 3552
# 3553
# 3554
# 3555
# 3556
# 3557
# 3558
# 3559
# 3560
# 3561
# 3562
# 3563
# 3564
# 3565
# 3566
# 3567
# 3568
# 3569
# 3570
# 3571
# 3572
# 3573
# 3574
# 3575
# 3576
# 3577
# 3578
# 3579
# 3580
# 3581
# 3582
# 3583
# 3584
# 3585
# 3586
# 3587
# 3588
# 3589
# 3590
# 3591
# 3592
# 3593
# 3594
# 3595
# 3596
# 3597
# 3598
# 3599
# 3600
# 3601
# 3602
# 3603
# 3604
# 3605
# 3606
# 3607
# 3608
# 3609
# 3610
# 3611
# 3612
# 3613
# 3614
# 3615
# 3616
# 3617
# 3618
# 3619
# 3620
# 3621
# 3622
# 3623
# 3624
# 3625
# 3626
# 3627
# 3628
# 3629
# 3630
# 3631
# 3632
# 3633
# 3634
# 3635
# 3636
# 3637
# 3638
# 3639
# 3640
# 3641
# 3642
# 3643
# 3644
# 3645
# 3646
# 3647
# 3648
# 3649
# 3650
# 3651
# 3652
# 3653
# 3654
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-51-004de0ef2ed7> in <module>()
#      11         if loc2:
#      12             #print(loc.raw['lat'],loc.raw['lng'])
# ---> 13             rev['lat'][idx]=loc2.raw['lat']
#      14             rev['lng'][idx]=loc2.raw['lng']
#      15
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/series.py in __setitem__(self, key, value)
#     935
#     936         # do the setitem
# --> 937         cacher_needs_updating = self._check_is_chained_assignment_possible()
#     938         setitem(key, value)
#     939         if cacher_needs_updating:
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in _check_is_chained_assignment_possible(self)
#    2622             if ref is not None and ref._is_mixed_type:
#    2623                 self._check_setitem_copy(stacklevel=4, t='referant',
# -> 2624                                          force=True)
#    2625             return True
#    2626         elif self._is_copy:
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in _check_setitem_copy(self, stacklevel, t, force)
#    2668             # the copy weakref
#    2669             try:
# -> 2670                 gc.collect(2)
#    2671                 if not gc.get_referents(self._is_copy()):
#    2672                     self._is_copy = None
#
# KeyboardInterrupt:

# %%
#rev.to_csv('data/reviews/AllreviewsWithCordinates', index=False)
# Out:
#              id                                               text  \
# 0      27077307  Amazing chef and humble human being. Willing t...
# 1      27152728  Amazing boy with amazing family . He met me up...
# 2      26922175  ￼\n\n \n\nWe use cookies to enhance your exper...
# 3      26866500  I was ill, when I come to Alexey's place, so I...
# 4      26818885  Didn't end up staying at his house because of....
# 5      26779351  С Алексеем было очень приятно и комфортно пров...
# 6      26176442  I had a great experience in Russia with Alexei...
# 1      2018-10-28T19:16:31Z   positive             surf       True
# 2      2018-09-27T14:41:06Z   positive             surf       True
# 3      2018-09-20T17:32:11Z   positive             surf       True
# 4      2018-09-15T05:17:31Z   positive             surf       True
# 5      2018-09-10T12:56:37Z   positive             surf       True
# 6      2018-07-10T13:57:26Z   positive             surf       True
# 7      2018-07-09T09:52:29Z   positive             surf       True
# 8      2018-07-07T16:05:53Z   positive             surf       True
# 9      2018-07-04T09:15:01Z   positive             surf       True
# 10     2018-06-28T14:23:37Z   positive             surf       True
# 11     2018-06-26T14:42:10Z   positive             surf       True
# 12     2018-06-20T14:32:53Z   positive             surf       True
# 13     2018-06-18T10:20:24Z   positive             surf       True
# 14     2018-06-16T09:22:08Z   positive             surf       True
# 15     2018-06-15T03:48:22Z   positive             surf       True
# 16     2018-06-11T06:47:07Z   positive             surf       True
# 17     2018-06-03T13:20:22Z   positive             surf       True
# 18     2018-06-01T11:02:21Z   positive             surf       True
# 19     2018-05-30T14:39:20Z   positive             surf       True
# 20     2018-05-28T09:46:08Z   positive             surf       True
# 21     2018-05-25T11:18:01Z   positive             surf       True
# 22     2018-11-18T12:05:08Z   positive             surf       True
# 23     2018-09-24T16:39:46Z   positive             surf       True
# 24     2018-09-09T17:07:32Z   positive             surf       True
# 25     2018-09-08T07:26:40Z   positive             surf       True
# 26     2018-08-04T10:06:42Z   positive             surf       True
# 27     2018-07-17T16:23:09Z   positive             surf       True
# 28     2018-05-24T13:04:25Z   positive             surf       True
# 29     2018-09-19T19:08:41Z   positive             surf       True
# ...                     ...        ...              ...        ...
# 95778  2013-09-23T16:21:39Z   positive             surf      False
# 95780  2013-09-21T15:23:05Z   positive             surf      False
# 95782  2013-09-18T10:05:19Z   positive             surf      False
# 95784  2013-09-16T09:51:32Z   positive             surf      False
# 95793  2013-07-17T16:38:17Z   positive             surf      False
# 95796  2013-07-01T15:48:19Z   positive             surf      False
# 95797  2013-06-23T04:27:47Z   positive             surf      False
# 95798  2013-06-13T14:31:25Z   positive             surf      False
# 95802  2013-05-13T19:33:34Z   positive             surf      False
# 95813  2013-03-28T18:05:18Z   positive             surf      False
# 95817  2013-02-22T16:29:54Z   positive             surf      False
# 95835  2013-01-20T22:34:03Z   positive             surf      False
# 95838  2013-01-06T15:38:15Z   positive             surf      False
# 95841  2012-12-29T15:36:39Z   positive             surf      False
# 95855  2012-12-03T10:34:11Z   positive             surf      False
# 95886  2012-10-17T16:27:00Z   positive             surf      False
# 95887  2012-10-16T23:33:47Z   positive             surf      False
# 95900  2012-09-20T12:10:38Z   positive             surf      False
# 95924  2012-07-24T16:47:50Z   positive             surf      False
# 95945  2012-05-02T10:43:12Z   positive             surf      False
# 95961  2012-02-12T12:09:28Z   positive             surf      False
# 95962  2012-02-07T16:11:18Z   positive             surf      False
# 96006  2014-08-08T11:54:43Z   positive             host      False
# 96012  2017-12-14T16:07:12Z   positive             surf       True
# 96029  2016-04-11T14:12:59Z   positive             surf       True
# 95924            7011624.0                            Zywiec, Silesia, Poland
# 95945            5937300.0                    Rottach-Egern, Bavaria, Germany
# 95961            4169195.0                           Mohacs, Baranya, Hungary
# 95962            4480169.0                 Castelli Calepio, Lombardia, Italy
# 96006            6070524.0                     Schipkau, Brandenburg, Germany
# 96012           12844761.0       Kurgan, Kurganskaya obl., Russian Federation
# 96029            5366934.0                               Lome, Maritime, Togo
# 96033            5873382.0     Gatchina, Leningrad Oblast, Russian Federation
# 96044          111216681.0                             Boynton Beach, FL, USA
# 96077            5667732.0         Chełm Śląski, Silesian Voivodeship, Poland
# 96085            8636350.0                        Terricciola, Toscana, Italy
# 96086            9410471.0                        Pontorson, Normandy, France
#
#                                            fromAvatarUrl fromStatus  \
# 0      https://s3.amazonaws.com/ht-images.couchsurfin...        yes
# 1      https://s3.amazonaws.com/ht-images.couchsurfin...         no
# 2      https://s3.amazonaws.com/ht-images.couchsurfin...      maybe
# 3      https://s3.amazonaws.com/ht-images.couchsurfin...      maybe
# 4      https://s3.amazonaws.com/images.couchsurfing.u...         no
# 5      https://s3.amazonaws.com/ht-images.couchsurfin...       hang
# 6      https://s3.amazonaws.com/ht-images.couchsurfin...         no
# 7      https://s3.amazonaws.com/ht-images.couchsurfin...         no
# 8      https://s3.amazonaws.com/ht-images.couchsurfin...       hang
# 9      https://s3.amazonaws.com/images.couchsurfing.u...      maybe
# 10     https://s3.amazonaws.com/ht-images.couchsurfin...        yes
# 11     https://s3.amazonaws.com/ht-images.couchsurfin...      maybe
# 12     https://s3.amazonaws.com/ht-images.couchsurfin...        yes
# 13     https://s3.amazonaws.com/ht-images.couchsurfin...        yes
# 14     https://s3.amazonaws.com/ht-images.couchsurfin...       hang
# 15     https://s3.amazonaws.com/ht-images.couchsurfin...         no
# 16     https://s3.amazonaws.com/ht-images.couchsurfin...        yes
# 17     https://s3.amazonaws.com/ht-images.couchsurfin...        yes
# 18     https://s3.amazonaws.com/ht-images.couchsurfin...        yes
# 19     https://s3.amazonaws.com/ht-images.couchsurfin...      maybe
# 20     https://s3.amazonaws.com/ht-images.couchsurfin...       hang
# 21     https://s3.amazonaws.com/ht-images.couchsurfin...       hang
# 22     https://s3.amazonaws.com/ht-images.couchsurfin...         no
# 23     https://s3.amazonaws.com/ht-images.couchsurfin...         no
# 24     https://s3.amazonaws.com/ht-images.couchsurfin...        yes
# 25     https://s3.amazonaws.com/ht-images.couchsurfin...      maybe
# 26     https://s3.amazonaws.com/ht-images.couchsurfin...       hang
# 27     https://s3.amazonaws.com/ht-images.couchsurfin...         no
# 28     https://s3.amazonaws.com/ht-images.couchsurfin...         no
# 29     https://s3.amazonaws.com/ht-images.couchsurfin...         no
# ...                                                  ...        ...
# 95778  https://s3.amazonaws.com/ht-images.couchsurfin...         no
# 95780  https://s3.amazonaws.com/images.couchsurfing.u...         no
# 95782  https://s3.amazonaws.com/images.couchsurfing.u...         no
# 95784  https://s3.amazonaws.com/images.couchsurfing.u...      maybe
# 95793  https://s3.amazonaws.com/images.couchsurfing.u...        yes
# 95796  https://s3.amazonaws.com/ht-images.couchsurfin...         no
# 95797  https://s3.amazonaws.com/ht-images.couchsurfin...         no
# 95798  https://s3.amazonaws.com/images.couchsurfing.u...         no
# 95802  https://s3.amazonaws.com/images.couchsurfing.u...        yes
# 95813  https://s3.amazonaws.com/images.couchsurfing.u...       hang
# 95817  https://s3.amazonaws.com/ht-images.couchsurfin...         no
# 95835  https://s3.amazonaws.com/ht-images.couchsurfin...       hang
# 95838  https://s3.amazonaws.com/ht-images.couchsurfin...         no
# 95841  https://s3.amazonaws.com/images.couchsurfing.u...      maybe
# 95855  https://s3.amazonaws.com/images.couchsurfing.u...      maybe
# 95886  https://s3.amazonaws.com/images.couchsurfing.u...       hang
# 95887  https://s3.amazonaws.com/images.couchsurfing.u...        yes
# 95900  https://s3.amazonaws.com/ht-images.couchsurfin...      maybe
# 95924  https://s3.amazonaws.com/images.couchsurfing.u...         no
# 95945  https://s3.amazonaws.com/images.couchsurfing.u...      maybe
# 95961  https://s3.amazonaws.com/images.couchsurfing.u...      maybe
# 95962  https://s3.amazonaws.com/ht-images.couchsurfin...       hang
# 96006  https://s3.amazonaws.com/images.couchsurfing.u...      maybe
# 96012  https://s3.amazonaws.com/images.couchsurfing.u...      maybe
# 96029  https://s3.amazonaws.com/images.couchsurfing.u...        yes
# 96033  https://s3.amazonaws.com/ht-images.couchsurfin...      maybe
# 96044  https://s3.amazonaws.com/ht-images.couchsurfin...         no
# 96077  https://s3.amazonaws.com/ht-images.couchsurfin...         no
# 96085  https://s3.amazonaws.com/images.couchsurfing.u...         no
# 96086  https://s3.amazonaws.com/images.couchsurfing.u...         no
#
#       fromIsVerified fromIsDeleted  fromBlockedBy  \
# 0               True         False            NaN
# 1              False         False            NaN
# 2              False         False            NaN
# 3              False         False            NaN
# 4              False         False            NaN
# 5               True         False            NaN
# 6              False         False            NaN
# 7              False         False            NaN
# 8              False         False            NaN
# 9              False         False            NaN
# 10             False         False            NaN
# 11             False         False            NaN
# 12              True         False            NaN
# 13              True         False            NaN
# 14             False         False            NaN
# 15             False         False            NaN
# 16             False         False            NaN
# 17              True         False            NaN
# 18              True         False            NaN
# 19              True         False            NaN
# 20             False         False            NaN
# 21             False         False            NaN
# 22             False         False            NaN
# 23             False         False            NaN
# 24              True         False            NaN
# 25             False         False            NaN
# 26             False         False            NaN
# 27             False         False            NaN
# 28             False         False            NaN
# 29             False         False            NaN
# ...              ...           ...            ...
# 95778          False         False            NaN
# 95780          False         False            NaN
# 95782          False         False            NaN
# 95784          False         False            NaN
# 95793          False         False            NaN
# 95796          False         False            NaN
# 95797          False         False            NaN
# 95798          False         False            NaN
# 95802          False         False            NaN
# 95813          False         False            NaN
# 95817          False         False            NaN
# 95835          False         False            NaN
# 95838          False         False            NaN
# 95841          False         False            NaN
# 95855          False         False            NaN
# 95886           True         False            NaN
# 95887           True         False            NaN
# 95900          False         False            NaN
# 95924          False         False            NaN
# 95945          False         False            NaN
# 95961          False         False            NaN
# 95962          False         False            NaN
# 96006          False         False            NaN
# 96012          False         False            NaN
# 96029          False         False            NaN
# 96033          False         False            NaN
# 96044          False         False            NaN
# 96077          False         False            NaN
# 96085          False         False            NaN
# 96086          False         False            NaN
#
#                                         inverseReference response        lat  \
# 0                                                    NaN      NaN    -6.2182
# 1                                                    NaN      NaN    25.0657
# 2                                                    NaN      NaN     37.566
# 3                                                    NaN      NaN    49.3961
# 4                                                    NaN      NaN  -35.28067
# 5                                                    NaN      NaN   58.59665
# 6                                                    NaN      NaN   30.29365
# 7                                                    NaN      NaN     37.566
# 8                                                    NaN      NaN   39.28808
# 9                                                    NaN      NaN    4.81333
# 10                                                   NaN      NaN   34.67279
# 11                                                   NaN      NaN   53.36056
# 12                                                   NaN      NaN   33.72148
# 13                                                   NaN      NaN    0.90258
# 14                                                   NaN      NaN     56.946
# 15                                                   NaN      NaN   59.93863
# 16                                                   NaN      NaN    4.60971
# 17                                                   NaN      NaN   47.36667
# 18                                                   NaN      NaN    4.60971
# 19                                                   NaN      NaN   59.93863
# 20                                                   NaN      NaN   55.72545
# 21                                                   NaN      NaN   55.75222
# 22                                                   NaN      NaN   54.74306
# 23                                                   NaN      NaN   50.45466
# 24                                                   NaN      NaN    14.6937
# 25                                                   NaN      NaN   56.99719
# 26                                                   NaN      NaN   25.28194
# 27                                                   NaN      NaN    55.0415
# 28                                                   NaN      NaN  -30.03306
# 29                                                   NaN      NaN   49.07515
# ...                                                  ...      ...        ...
# 95778  {'id': '11562934', 'text': 'I hosted Jenn & Ch...      NaN        NaN
# 95780  {'id': '14112337', 'text': "Actually we didn't...      NaN        NaN
# 95782  {'id': '13893481', 'text': 'ADVICE FOR READERS...      NaN        NaN
# 95784  {'id': '13893517', 'text': 'ADVICE FOR READERS...      NaN        NaN
# 95793  {'id': '11836349', 'text': 'Flo surfed my hous...      NaN        NaN
# 95796  {'id': '13273741', 'text': 'I hosted Sabrina &...      NaN        NaN
# 95797  {'id': '13286377', 'text': 'I hosted Valentina...      NaN        NaN
# 95798  {'id': '13241979', 'text': 'Melanie... such a ...      NaN        NaN
# 95802  {'id': '13018903', 'text': "We shared the most...      NaN        NaN
# 95813  {'id': '12697785', 'text': "I'm honored to hos...      NaN        NaN
# 95817  {'id': '12469751', 'text': 'Actually, when I c...      NaN        NaN
# 95835  {'id': '12290199', 'text': 'TA DAAA!!! Finally...      NaN        NaN
# 95838  {'id': '12205000', 'text': "Sebastian is a SUN...      NaN        NaN
# 95841  {'id': '12165033', 'text': "Strange but true.....      NaN        NaN
# 95855  {'id': '11988293', 'text': "I just sent a welc...      NaN        NaN
# 95886  {'id': '11640157', 'text': "If I had not accep...      NaN        NaN
# 95887  {'id': '11560507', 'text': 'After lot of messa...      NaN        NaN
# 95900  {'id': '11400251', 'text': 'Marco... you know,...      NaN        NaN
# 95924  {'id': '10713106', 'text': "Although I have ho...      NaN        NaN
# 95945  {'id': '9971591', 'text': "I hosted Franziska ...      NaN        NaN
# 95961  {'id': '9429858', 'text': 'I hosted her + othe...      NaN        NaN
# 95962  {'id': '9415917', 'text': 'Michele is very nic...      NaN        NaN
# 96006  {'id': '15974493', 'text': 'Was travelling on ...      NaN        NaN
# 96012                                                NaN      NaN        NaN
# 96029                                                NaN      NaN        NaN
# 96033                                                NaN      NaN        NaN
# 96044                                                NaN      NaN        NaN
# 96077  {'id': '17505969', 'text': 'Agata and her frie...      NaN        NaN
# 96085  {'id': '14184174', 'text': 'Since the first CS...      NaN        NaN
# 96086  {'id': '14071944', 'text': "Florence choosed m...      NaN        NaN
#
#              lng
# 0       106.8306
# 1       55.17128
# 2       126.9784
# 3       15.59124
# 4      174.09103
# 5       49.66007
# 6      120.16142
# 7       126.9784
# 8      -76.61076
# 9      -75.69611
# 10         3.263
# 11      83.76361
# 12      73.04329
# 13     109.32234
# 14      24.10589
# 15      30.31413
# 16     -74.08175
# 17          8.55
# 18     -74.08175
# 19      30.31413
# 20      52.41122
# 21      37.61556
# 22      55.96779
# 23       30.5238
# 24     -17.44406
# 25      40.97139
# 26     110.28639
# 27       82.9346
# 28        -51.23
# 29      17.43338
# ...          ...
# 95778        NaN
# 95780        NaN
# 95782        NaN
# 95784        NaN
# 95793        NaN
# 95796        NaN
# 95797        NaN
# 95798        NaN
# 95802        NaN
# 95813        NaN
# 95817        NaN
# 95835        NaN
# 95838        NaN
# 95841        NaN
# 95855        NaN
# 95886        NaN
# 95887        NaN
# 95900        NaN
# 95924        NaN
# 95945        NaN
# 95961        NaN
# 95962        NaN
# 96006        NaN
# 96012        NaN
# 96029        NaN
# 96033        NaN
# 96044        NaN
# 96077        NaN
# 96085        NaN
# 96086        NaN
#
# [19334 rows x 20 columns]

# %%
G = nx.MultiDiGraph()
links = []
user_id_unique=set(hosts['id'].tolist())
G.add_nodes_from([(rows['name'],{'lat':rows['lat'],'lng':rows['lng']}) for idx,rows in cities.iterrows()])
G.add_nodes_from([(rows['fromPublicAddressDescription'],{'lat':rows['lat'],'lng':rows['lng']}) for idx,rows in rev.iterrows() if rows['lat'] !='NaN' rows['lng']!='NaN')
for idx,r in rev.iterrows():
    #if r['from'] in hosts['id'].tolist() and r['to'] in hosts['id'].tolist():
    if r['from'] in G.nodes().tolist()
        if r['relationshipType']=='surf':
            G.add_edge(hosts.loc[hosts['id']==r['from']]['city'].item(),hosts.loc[hosts['id']==r['to']]['city'].item())
        if r['relationshipType']=='host':
            G.add_edge(hosts.loc[hosts['id']==r['to']]['city'].item(),hosts.loc[hosts['id']==r['from']]['city'].item())
#G.add_edges_from([(rows['to'],rows['from'])for index,rows in rev[['to','from','relationshipType']].iterrows() if rows['relationshipType']=='host' and G.has_node(rows['to']) and G.has_node(rows['from'])])
#G.add_edges_from([(rows['from'],rows['to'])for index,rows in rev[['to','from','relationshipType']].iterrows() if rows['relationshipType']=='surf' and G.has_node(rows['to']) and G.has_node(rows['from'])])

# %%
plt.figure(figsize = (10,9))
m = Basemap(projection='merc',llcrnrlon=-30,llcrnrlat=25,urcrnrlon=50,
urcrnrlat=70, lat_ts=0, resolution='l',suppress_ticks=True)
mx, my = m(cities['lng'].values, cities['lat'].values)
pos = {}
for count, elem in enumerate (cities['name']):
     pos[elem] = (mx[count], my[count])

nx.draw_networkx_nodes(G, pos = pos, node_list =G.nodes() ,node_color = 'firebrick', alpha = 0.8, node_size = [v[1] * 3 for v in G.degree()])
nx.draw_networkx_edges(G, pos = pos, edge_color='cornflowerblue', alpha=0.2, arrows = False)
#nx.draw_networkx_edges(G, pos = pos, edge_color='g', alpha=0.2, arrows = False)
m.drawcountries(linewidth = 3)
#m.drawstates(linewidth = 0.2)
m.drawcoastlines(linewidth=3)
m.bluemarble()
plt.tight_layout()
plt.savefig("map.png", format = "png", dpi = 300)

plt.show()
