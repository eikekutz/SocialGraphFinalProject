# %%
import pandas as pd
import matplotlib.pyplot as plt
from fa2 import ForceAtlas2
import numpy as np
import csv
import networkx as nx
import os

# %%
from couchsurfing import Api

# %%
#Denmark
#Get the cities from list (Wikipedia)
cities = pd.read_csv('data/Top50/top50cities.csv',delimiter=',')

# %%
cities
# Out:
#     Unnamed: 0             name  population       lat       lng  countryId  \
# 0            0           Moscow    10381222  55.75222  37.61556    2017370
# 1            1           London     7556900  51.50853  -0.12574    2635167
# 2            2    St Petersburg     5028000  59.93863  30.31413    2017370
# 3            3           Berlin     3426354  52.52437  13.41053    2921044
# 4            4           Madrid     3255944  40.41650  -3.70256    2510769
# 5            5             Rome     2318895  41.89193  12.51133    3175395
# 6            6             Kyiv     2797553  50.45466  30.52380     690791
# 7            7            Paris     2138551  48.85341   2.34880    3017382
# 8            8        Bucharest     1877155  44.43225  26.10626     798549
# 9            9         Budapest     1741041  47.49801  19.03991     719819
# 10          10          Hamburg     1739117  53.57532  10.01534    2921044
# 11          11            Minsk     1742124  53.90000  27.56667     630336
# 12          12           Warsaw     1702139  52.22977  21.01178     798544
# 13          13         Belgrade     1273651  44.80401  20.46513    6290252
# 14          14           Vienna     1691468  48.20849  16.37208    2782113
# 15          15          Kharkiv     1430885  49.98081  36.25272     690791
# 16          16        Barcelona     1621537  41.38879   2.15899    2510769
# 17          17      Novosibirsk     1419007  55.04150  82.93460    2017370
# 18          18  Nizhny Novgorod     1284164  56.32867  44.00205    2017370
# 19          19            Milan     1236837  45.46427   9.18951    3175395
#
#        countryName countryCode            fclName  geonameId
# 0           Russia          RU  city, village,...     524901
# 1   United Kingdom          GB  city, village,...    2643743
# 2           Russia          RU  city, village,...     498817
# 3          Germany          DE  city, village,...    2950159
# 4            Spain          ES  city, village,...    3117735
# 5            Italy          IT  city, village,...    3169070
# 6          Ukraine          UA  city, village,...     703448
# 7           France          FR  city, village,...    2988507
# 8          Romania          RO  city, village,...     683506
# 9          Hungary          HU  city, village,...    3054643
# 10         Germany          DE  city, village,...    2911298
# 11         Belarus          BY  city, village,...     625144
# 12          Poland          PL  city, village,...     756135
# 13          Serbia          RS  city, village,...     792680
# 14         Austria          AT  city, village,...    2761369
# 15         Ukraine          UA  city, village,...     706483
# 16           Spain          ES  city, village,...    3128760
# 17          Russia          RU  city, village,...    1496747
# 18          Russia          RU  city, village,...     520555
# 19           Italy          IT  city, village,...     317343

# %%
#Create API
api = Api('jacob2312@protonmail.com','Jacob2312')

# %%
#def get_hosts_latlong(self,latitude=10,longitude=10,page=1,perPage=100,radius=10):

def getHostFromCity(city,latitude,longitude):
    print("Getting results for ",city,latitude,longitude)
    for p in range(1,15):
        print(p)
        ##hosts = api.get_hosts(city,25,100,p)
        ##hosts = api.get_hosts(city,25,100,None,'best_match',"yes,maybe",None,p,last_login)
        hosts = api.get_hosts_latlong(latitude,longitude,p,100,25,4)
        writeCityResults2File(hosts,city,p)
        sleep(randint(2,5))
    
def writeCityResults2File(results,cityString,page):
    with open('data/Top50/hosts/'+cityString+str(page)+'.csv','w',newline="") as f:
        writer = csv.writer(f,delimiter = ',')
        # Write CSV Header, If you dont need that, remove this line
        writer.writerow(["id",
                "publicName",
                "avatarUrl",
                "isVerified",
                "status",
                "lastLogin",
                "aboutText",
                "responseRate",
                "responseTimeText",
                'responseRateText',
                "totalReferencesCount",
                "profileLink",
                "friendsCount",
                "languages",
                "city"])

        for host in results['results']:
            writer.writerow([host["id"],
                    host["publicName"],
                    host["avatarUrl"],
                    host["isVerified"],
                    host["status"],
                    host["lastLogin"],
                    host["aboutText"],
                    host["responseRate"],
                    host["responseTimeText"],
                    host["responseRateText"],
                    host["totalReferencesCount"],
                    host["profileLink"],
                    host["friendsCount"],
                    host["languages"],
                    cityString])

# %%
#import nodes to get id from nodes/hosts
def importHosts(index):
    hosts = pd.DataFrame() #creates a new dataframe that's empty
    city = cities.loc[index]
    for p in range(1,15):
        if (os.path.exists('data/Top50/hosts/'+city['name']+str(p)+'.csv')):
            df = pd.read_csv('data/Top50/hosts/'+city['name']+str(p)+'.csv')
            hosts = pd.concat([hosts,df]).reset_index(drop=True)
    return hosts

# %%
def createRevCityList(city): 
    with open('data/Top50/reviews/'+city+'Rev.csv','w',newline="") as f:
            writer = csv.writer(f,delimiter = ',')
            writer.writerow(["id",
                    "text",
                    "createdDate",
                    "experience",
                    "relationshipType",
                    "isPostTrip",
                    "to",
                    "from",
                    "fromPublicName",
                    "fromPublicAddressId",
                    "fromPublicAddressDescription"
                    "fromAvatarUrl",
                    "fromStatus",
                    "fromIsVerified",
                    "fromIsDeleted",
                    "fromBlockedBy",
                    "inverseReference",
                    "response"])

# %%
def appendReview(file,city):
    with open('data/Top50/reviews/'+city+'Rev.csv','a',newline="") as f:
        writer = csv.writer(f,delimiter = ',')
        for host in file['results']:
            writer.writerow([host["id"],
                host["text"],
                host["createdDate"],
                host["experience"],
                host["relationshipType"],
                host["isPostTrip"],
                host["to"]['id'],
                host["from"]['id'],
                host["from"]["publicName"],
                host["from"]["publicAddress"]["id"],
                host["from"]["publicAddress"]["description"],
                host["from"]["avatarUrl"],
                host["from"]["status"],
                host["from"]["isVerified"],
                host["from"]["isDeleted"],
                host["from"]["blockedBy"],
                host["inverseReference"],
                host["response"]])

# %%
def getReferenceForCity(index):
    hosts= importHosts(index=index)
    city = cities.loc[index]
    print("Getting results for ",city['name'])
    createRevCityList(city['name'])
    #exception for one user in Berlin id = 1005431874,3570008
    #startHost= hosts.index[hosts['id']==3570008]
    #startHost=startHost.tolist()[0]
    for idx,host in hosts.iterrows():
     #   if idx>startHost:
        print(host['id'])
        test=api.get_references(uid=host['id'],type='host')
        appendReview(test,city['name'])
        test=api.get_references(uid=host['id'],type='surf')
        appendReview(test,city['name'])

# %%
from random import randint
from time import sleep
#Get the the hosts
for idx,city in cities.iterrows():#.loc[cities['2017']>50000].iterrows():
        getHostFromCity(city['name'],city['lat'],city['lng'])
        sleep(randint(10,20))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     379             try:  # Python 2.7, use buffering of HTTP responses
# --> 380                 httplib_response = conn.getresponse(buffering=True)
#     381             except TypeError:  # Python 2.6 and older, Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-24-269068d7bfb2> in <module>()
#       4 for idx,city in cities.iterrows():#.loc[cities['2017']>50000].iterrows():
#       5         #getHostFromCity(city['name'],city['lat'],city['lng'])
# ----> 6         getReference(idx)
#       7         sleep(randint(10,20))
#
# <ipython-input-13-b8ec5622ce5c> in getReference(index)
#       4     createRevCityList(city['name'])
#       5     for host in hosts['id']:
# ----> 6         test=api.get_references(uid=host,type='host')
#       7         appendReview(test,city['name'])
#       8         test=api.get_references(uid=host,type='surf')
#
# ~/DTU/SocialGraphsAndInteractions/FinalProject/Couchsurfing/couchsurfing/api.py in get_references(self, uid, type, perPage)
#     236         )
#     237
# --> 238         return self.api_request(path)
#     239
#     240
#
# ~/DTU/SocialGraphsAndInteractions/FinalProject/Couchsurfing/couchsurfing/api.py in api_request(self, path)
#     102         })
#     103         #print('CS_URL+path',CS_URL+path)
# --> 104         r = self._session.get(CS_URL + path)
#     105
#     106         if (r.status_code != 200):
#
# ~/anaconda3/lib/python3.6/site-packages/requests/sessions.py in get(self, url, **kwargs)
#     519
#     520         kwargs.setdefault('allow_redirects', True)
# --> 521         return self.request('GET', url, **kwargs)
#     522
#     523     def options(self, url, **kwargs):
#
# ~/anaconda3/lib/python3.6/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     506         }
#     507         send_kwargs.update(settings)
# --> 508         resp = self.send(prep, **send_kwargs)
#     509
#     510         return resp
#
# ~/anaconda3/lib/python3.6/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     616
#     617         # Send the request
# --> 618         r = adapter.send(request, **kwargs)
#     619
#     620         # Total elapsed time of the request (approximately)
#
# ~/anaconda3/lib/python3.6/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     438                     decode_content=False,
#     439                     retries=self.max_retries,
# --> 440                     timeout=timeout
#     441                 )
#     442
#
# ~/anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     599                                                   timeout=timeout_obj,
#     600                                                   body=body, headers=headers,
# --> 601                                                   chunked=chunked)
#     602
#     603             # If we're going to release the connection in ``finally:``, then
#
# ~/anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     381             except TypeError:  # Python 2.6 and older, Python 3
#     382                 try:
# --> 383                     httplib_response = conn.getresponse()
#     384                 except Exception as e:
#     385                     # Remove the TypeError from the exception chain in Python 3;
#
# ~/anaconda3/lib/python3.6/http/client.py in getresponse(self)
#    1329         try:
#    1330             try:
# -> 1331                 response.begin()
#    1332             except ConnectionError:
#    1333                 self.close()
#
# ~/anaconda3/lib/python3.6/http/client.py in begin(self)
#     295         # read until we get a non-100 response
#     296         while True:
# --> 297             version, status, reason = self._read_status()
#     298             if status != CONTINUE:
#     299                 break
#
# ~/anaconda3/lib/python3.6/http/client.py in _read_status(self)
#     256
#     257     def _read_status(self):
# --> 258         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     259         if len(line) > _MAXLINE:
#     260             raise LineTooLong("status line")
#
# ~/anaconda3/lib/python3.6/socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# ~/anaconda3/lib/python3.6/site-packages/urllib3/contrib/pyopenssl.py in recv_into(self, *args, **kwargs)
#     278     def recv_into(self, *args, **kwargs):
#     279         try:
# --> 280             return self.connection.recv_into(*args, **kwargs)
#     281         except OpenSSL.SSL.SysCallError as e:
#     282             if self.suppress_ragged_eofs and e.args == (-1, 'Unexpected EOF'):
#
# ~/anaconda3/lib/python3.6/site-packages/OpenSSL/SSL.py in recv_into(self, buffer, nbytes, flags)
#    1811             result = _lib.SSL_peek(self._ssl, buf, nbytes)
#    1812         else:
# -> 1813             result = _lib.SSL_read(self._ssl, buf, nbytes)
#    1814         self._raise_ssl_error(self._ssl, result)
#    1815
#
# KeyboardInterrupt:

# %%
for idx,city in cities.iterrows():#.loc[cities['2017']>50000].iterrows():
    if idx>8:
        getReferenceForCity(idx)
        sleep(randint(5,10))
# Out:
# Getting results for  Budapest
# 2007820574
# 2008009150
# 2007798486
# 2008535497
# 2007539879
# 2008365495
# 2007366181
# 2008727955
# 2007482900
# 2007700991
# 2007893687
# 2004460523
# 1006015895
# 2008671998
# 2008440140
# 2008756054
# 2009563219
# 2004721973
# 787537
# 2927560
# 2007746389
# 2003524550
# 2004079282
# 2007340101
# 2007455359
# 2004727438
# 2004954836
# 2008144805
# 2009291869
# 2001111913
# 2007617550
# 460660
# 2005038333
# 2009010789
# 2008140301
# 1004555866
# 2006182090
# 2006642324
# 2007254650
# 3045927
# 2005784160
# 1007500834
# 2006591616
# 2009428483
# 2007839331
# 2007210277
# 2001405191
# 1974479
# 2005312682
# 4788234
# 2006469742
# 557168
# 1003426137
# 1305506
# 1249036
# 2603069
# 1005044621
# 1005128501
# 2007697975
# 1006131158
# 1001118581
# 1000409495
# 1002589164
# 2001895974
# 2007838968
# 2000476021
# 2009573203
# 2005509390
# 5470611
# 3387643
# 2008084974
# 2871864
# 2001549133
# 2000733713
# 1005624261
# 2000899987
# 2001401113
# 1299576
# 2007747958
# 2006534884
# 3786366
# 2206330
# 2001288735
# 2008698425
# 2005343665
# 1098848
# 2003746940
# 2714335
# 2007066169
# 2002629882
# 5257581
# 4388141
# 1005794537
# 1005500243
# 2003341210
# 2001370842
# 1007568900
# 2008439492
# 1003955480
# 2003867147
# 2006168768
# 2004388295
# 5260676
# 2004003582
# 2008126466
# 2008565621
# 1002645862
# 2009037987
# 2006779464
# 2006714484
# 1034879
# 2002802773
# 3788897
# 2004541493
# 2000484727
# 2007139429
# 1002541102
# 2073418
# 2727991
# 2388523
# 1007219271
# 2001493490
# 451  2005778060           Dwarak Chaluvadi
# 452  1004722778                Julia Stock
# 453  1001988991               Jannes Meyer
# 454  2005172478           Reinhard Strömer
# 455     4524899               Denis Hamann
# 456  1000040922                  Carl Cole
# 457  2005763328               Lina Rickert
# 458  2005999191           Catherine Greven
#
#                                              avatarUrl isVerified status  \
# 0    https://tcdn.couchsurfing.com/849K74eKDSYUGj9a...       True    yes
# 1    https://tcdn.couchsurfing.com/Gi1fqNE3djnMGkS_...       True  maybe
# 2    https://tcdn.couchsurfing.com/pF00-pO8Pg72owhK...       True    yes
# 3    https://tcdn.couchsurfing.com/1IsSZ5QMsdc1b7S1...       True  maybe
# 4    https://tcdn.couchsurfing.com/fGei1IawaxuZV7fI...       True  maybe
# 5    https://tcdn.couchsurfing.com/rqlMTjYx6HcgZhql...       True  maybe
# 6    https://tcdn.couchsurfing.com/f7INbS3IiLaPhZil...       True    yes
# 7    https://tcdn.couchsurfing.com/pEs-DmLm0ohYvy_I...       True  maybe
# 8    https://tcdn.couchsurfing.com/Dzo6cQq8-tkBAdnh...       True    yes
# 9    https://tcdn.couchsurfing.com/nyaHP13r0DXiDUki...       True  maybe
# 10   https://tcdn.couchsurfing.com/gmnZ03VigFlvCWbx...       True  maybe
# 11   https://tcdn.couchsurfing.com/7l-B6YgC3Zk-SrNv...       True    yes
# 12   https://tcdn.couchsurfing.com/qwDeDf9wULapQ1No...       True  maybe
# 13   https://tcdn.couchsurfing.com/jZjmO5W6uai9OOli...       True  maybe
# 14   https://tcdn.couchsurfing.com/U5sLPQzWg71NlM21...       True  maybe
# 15   https://tcdn.couchsurfing.com/uZJZId_4KrdjgUt1...       True    yes
# 16   https://tcdn.couchsurfing.com/tzA49DSo9WMIA2l7...       True    yes
# 17   https://tcdn.couchsurfing.com/8sEC2UjZ8UlXWFhL...       True  maybe
# 18   https://tcdn.couchsurfing.com/kTXVjYF8fT3YiLen...       True    yes
# 19   https://tcdn.couchsurfing.com/C195j15eMTVZRSWr...       True  maybe
# 20   https://tcdn.couchsurfing.com/ykavcewcGTHA_e5C...       True    yes
# 21   https://tcdn.couchsurfing.com/W0QitXk2nE40avCI...       True    yes
# 22   https://tcdn.couchsurfing.com/vnXxXEvS3fm8KrrT...       True  maybe
# 23   https://tcdn.couchsurfing.com/NPtHBwdpB0msVdz5...       True    yes
# 24   https://tcdn.couchsurfing.com/SVNvwZiVbzYGHsG2...       True    yes
# 25   https://tcdn.couchsurfing.com/NOKlJZa2UfmfEdTs...       True    yes
# 26   https://tcdn.couchsurfing.com/NK_j3NwK2taTTV2B...       True    yes
# 27   https://tcdn.couchsurfing.com/z556P8QbEGX3Xfqn...       True  maybe
# 28   https://tcdn.couchsurfing.com/TI4gprRk_kXaVdDb...       True  maybe
# 29   https://tcdn.couchsurfing.com/HIl5fb1lzELAqw-Q...       True    yes
# ..                                                 ...        ...    ...
# 429  https://tcdn.couchsurfing.com/fR0BQgxYrew9IT_U...       True  maybe
# 430  https://tcdn.couchsurfing.com/pU9rdAUI8lHSc1Fo...       True  maybe
# 431  https://tcdn.couchsurfing.com/nImCrEvCs4PH6pta...       True  maybe
# 432  https://tcdn.couchsurfing.com/CFPl1nCMwyFhCx02...       True    yes
# 433  https://tcdn.couchsurfing.com/M3k0zcvVf7wctIu9...       True  maybe
# 434  https://tcdn.couchsurfing.com/ZzQgWRYErRHy7aaZ...       True  maybe
# 435  https://tcdn.couchsurfing.com/PKWorXzCtwhTk4-g...       True    yes
# 436  https://tcdn.couchsurfing.com/9PEXu4kfPIHSa8ic...       True    yes
# 437  https://tcdn.couchsurfing.com/5ybPkn9-qrM2xMtp...       True    yes
# 438  https://tcdn.couchsurfing.com/_E-YTN880awLnAMO...       True    yes
# 439  https://tcdn.couchsurfing.com/OclexZu3BRy5po1_...       True  maybe
# 440  https://tcdn.couchsurfing.com/poGaxsCFc8QFk5TD...      False    yes
# 441  https://tcdn.couchsurfing.com/lWHHYVTuZXwe1IOC...       True    yes
# 442  https://tcdn.couchsurfing.com/pqUv8JEiNSJWol15...       True  maybe
# 443  https://tcdn.couchsurfing.com/OriRRo5thO7nbUKx...       True  maybe
# 444  https://tcdn.couchsurfing.com/z7wBqCwkMJgbTpJG...       True  maybe
# 445  https://tcdn.couchsurfing.com/nU5pIVO1gmp5OSRX...       True  maybe
# 446  https://tcdn.couchsurfing.com/vKBFIeXswXBe-zcZ...       True  maybe
# 447  https://tcdn.couchsurfing.com/-PGjYcneGB2VQwGR...       True    yes
# 448  https://tcdn.couchsurfing.com/xMDNssYV4pJNK3Me...       True  maybe
# 449  https://tcdn.couchsurfing.com/ya2tSzLuTkpJlWHO...       True  maybe
# 450  https://tcdn.couchsurfing.com/Xyf7ruvUb7JaPoGb...       True  maybe
# 451  https://tcdn.couchsurfing.com/DD9Jep_apxKHscNY...       True  maybe
# 452  https://tcdn.couchsurfing.com/tlHGlqW-fJl3hHj0...       True  maybe
# 453  https://tcdn.couchsurfing.com/wKZxiuwQ_7KNdrxr...       True  maybe
# 454  https://tcdn.couchsurfing.com/WbQM4Epzt7dH0x1o...       True  maybe
# 455  https://tcdn.couchsurfing.com/W76d9fDjNJDf5UGV...       True  maybe
# 456  https://tcdn.couchsurfing.com/GJ8Og9eyzL4xfRHF...       True  maybe
# 457  https://tcdn.couchsurfing.com/miTcKK9Qzzij4LhV...       True  maybe
# 458  https://tcdn.couchsurfing.com/pE9nkMhIBs4Y2M28...       True  maybe
#
#           lastLogin                                          aboutText  \
# 0    about 11 hours  \nI’m not a fan of writing too much about myse...
# 1    about 11 hours  Right now I'm studying Tourims-, Hotel- and Ev...
# 2         6 minutes  OFF FROM HOSTING AND ONLY REPLY YOUR MESSAGE T...
# 3     about 3 hours  Hi, I am a german-finnish Longboarder, who rea...
# 4    about 21 hours  Ich bin aufgeschlossen, manchmal verrückt, kan...
# 5      about 1 hour  I am quite busy at the moment, could host you ...
# 456        3 months  ABOUT ME\n\nThey would say that i am an honest...
# 457        4 months  Just finished high school, exploring the real ...
# 458   about 1 month                                                NaN
#
#     responseRate                   responseTimeText    responseRateText  \
# 0            100               replies within a day  100% response rate
# 1            100            replies within 1-3 days  100% response rate
# 2            100               replies within a day  100% response rate
# 3             81              replies within a week   81% response rate
# 4             92              replies within a week   92% response rate
# 5            100            replies within 1-3 days  100% response rate
# 6             90            replies within 1-3 days   90% response rate
# 7             -1               replies within a day   -1% response rate
# 8            100               replies within a day  100% response rate
# 9             91            replies within 1-3 days   91% response rate
# 10            -1  takes longer than a week to reply   -1% response rate
# 11            98            replies within 1-3 days   98% response rate
# 12            83              replies within a week   83% response rate
# 13           100            replies within 1-3 days  100% response rate
# 14            84              replies within a week   84% response rate
# 15           100              replies within a week  100% response rate
# 16            96            replies within 1-3 days   96% response rate
# 17            92            replies within 1-3 days   92% response rate
# 18            81              replies within a week   81% response rate
# 19            90              replies within a week   90% response rate
# 20            61  takes longer than a week to reply   61% response rate
# 21            90              replies within a week   90% response rate
# 22            88              replies within a week   88% response rate
# 23            83              replies within a week   83% response rate
# 24           100               replies within a day  100% response rate
# 25            96              replies within a week   96% response rate
# 26           100               replies within a day  100% response rate
# 27            96            replies within 1-3 days   96% response rate
# 28            98               replies within a day   98% response rate
# 29           100               replies within a day  100% response rate
# ..           ...                                ...                 ...
# 429           -1  takes longer than a week to reply   -1% response rate
# 430           -1  takes longer than a week to reply   -1% response rate
# 431            0  takes longer than a week to reply    0% response rate
# 432           -1  takes longer than a week to reply   -1% response rate
# 433           -1  takes longer than a week to reply   -1% response rate
# 434           -1  takes longer than a week to reply   -1% response rate
# 435           -1  takes longer than a week to reply   -1% response rate
# 436           -1  takes longer than a week to reply   -1% response rate
# 437           -1  takes longer than a week to reply   -1% response rate
# 438           -1  takes longer than a week to reply   -1% response rate
# 439            0  takes longer than a week to reply    0% response rate
# 440            0  takes longer than a week to reply    0% response rate
# 441           50  takes longer than a week to reply   50% response rate
# 442           -1  takes longer than a week to reply   -1% response rate
# 443            0  takes longer than a week to reply    0% response rate
# 444           -1               replies within a day   -1% response rate
# 445           -1  takes longer than a week to reply   -1% response rate
# 446           -1  takes longer than a week to reply   -1% response rate
# 447            0  takes longer than a week to reply    0% response rate
# 448           -1  takes longer than a week to reply   -1% response rate
# 449           66              replies within a week   66% response rate
# 450           -1  takes longer than a week to reply   -1% response rate
# 451           -1  takes longer than a week to reply   -1% response rate
# 452           -1  takes longer than a week to reply   -1% response rate
# 453           -1  takes longer than a week to reply   -1% response rate
# 454           -1               replies within a day   -1% response rate
# 455           -1  takes longer than a week to reply   -1% response rate
# 456           -1  takes longer than a week to reply   -1% response rate
# 457            0  takes longer than a week to reply    0% response rate
# 458           -1  takes longer than a week to reply   -1% response rate
#
#     totalReferencesCount                     profileLink friendsCount  \
# 0                      4           /people/roman-kliewer            6
# 1                      9             /people/joshua-buck            6
# 2                     25         /people/farhan-alfarisi           35
# 3                      7           /people/sime-lamerdin            7
# 4                      4       /people/nadine-hoffmann-4            1
# 5                      9               /users/2008981650            9
# 6                      7        /people/julius-oldehaver            3
# 7                      9                  /people/banang           13
# 8                      6               /users/2008284007            6
# 9                     11        /people/kathleen-maennel            8
# 10                     8      /people/margarethe-groos-1           11
# 11                    48        /people/christinehamburg           37
# 12                    20          /people/paul-kobelev-1           31
# 13                     1             /people/dapo-daniel            1
# 14                    10                  /people/drcala           17
# 15                     2         /people/laura.jllenbeck           15
# 16                    12         /people/philip_hamburgo            6
# 17                    45      /people/marleen-krumbiegel           42
# 18                     6       /people/julian-steocklein           18
# 19                    15              /people/bea-luebke           19
# 20                    13       /people/gunnar-brunkhorst           26
# 21                     9           /people/hussein-mouhi           14
# 22                     8          /people/linnea-heymann            7
# 23                    11          /people/farouk-sellami           16
# 24                    83  /people/karsten.goldie.schulze          168
# 25                    35        /people/stefan-ferrara-1           35
# 26                    21       /people/tony_the_explorer           22
# 27                     1           /people/max-nielsen-2            0
# 28                    33               /users/1004254738           23
# 29                     4                /people/dannidon           14
# ..                   ...                             ...          ...
# 429                    0              /people/david-redh            0
# 430                    0          /people/vlad-serdyuk-1            0
# 431                    0              /people/till-ost-1            0
# 432                    0      /people/christinschleuning            3
# 433                    0         /people/mara-jendryssek            0
# 434                    0         /people/carsten-freitag            0
# 435                    0            /people/carsten-otto           12
# 436                    0          /people/vincent-handke           12
# 437                    0           /people/hans-ratzmann            5
# 438                    0             /people/stephan-hah            1
# 439                    0  /people/julia-guenther-borstel            0
# 440                    0              /people/lydia.lbke            1
# 441                   24              /people/maglev1234           44
# 442                    0         /people/lisa-hellriegel            3
# 443                    0       /people/sepideh-sadighnia            0
# 444                    3               /users/2006273685            2
# 445                    0                /people/aschmutt            4
# 446                    0          /people/moritz-hohmann            3
# 447                    0              /people/miriam4321            0
# 448                    0            /people/tessapittrof            0
# 449                    0   /people/natalia-derevesnikova            0
# 450                    0               /users/2005222326            1
# 451                    0        /people/dwarak-chaluvadi            5
# 452                    0              /people/juliastock            0
# 453                    0             /people/jannesmeyer            0
# 454                    0               /users/2005172478            0
# 455                    0             /people/denishamann            3
# 456                    0               /people/carl-cole            0
# 457                    1               /people/lina-ri-1            0
# 458                    0        /people/catherine-greven            1
#
#                                              languages     city
# 0                                       {'fluent': []}  Hamburg
# 1    {'fluent': [{'code': 'deu', 'name': 'German'},...  Hamburg
# 2    {'fluent': [{'code': 'deu', 'name': 'German'},...  Hamburg
# 3    {'fluent': [{'code': 'deu', 'name': 'German'},...  Hamburg
# 4    {'fluent': [{'code': 'deu', 'name': 'German'},...  Hamburg
# 5    {'fluent': [{'code': 'eng', 'name': 'English'}...  Hamburg
# 6    {'fluent': [{'code': 'deu', 'name': 'German'},...  Hamburg
# 7    {'fluent': [{'code': 'deu', 'name': 'German'},...  Hamburg
# 8                                       {'fluent': []}  Hamburg
# 9                                       {'fluent': []}  Hamburg
# 10   {'fluent': [{'code': 'deu', 'name': 'German'},...  Hamburg
# 11   {'fluent': [{'code': 'deu', 'name': 'German'},...  Hamburg
# 12   {'fluent': [{'code': 'eng', 'name': 'English'}...  Hamburg
# 13   {'fluent': [{'code': 'eng', 'name': 'English'}...  Hamburg
# 14   {'fluent': [{'code': 'spa', 'name': 'Spanish'}...  Hamburg
# 15   {'fluent': [{'code': 'deu', 'name': 'German'},...  Hamburg
# 16   {'fluent': [{'code': 'deu', 'name': 'German'},...  Hamburg
# 17   {'fluent': [{'code': 'eng', 'name': 'English'}...  Hamburg
# 18   {'fluent': [{'code': 'deu', 'name': 'German'},...  Hamburg
# 19   {'fluent': [{'code': 'deu', 'name': 'German'},...  Hamburg
# 20   {'fluent': [{'code': 'eng', 'name': 'English'}...  Hamburg
# 21   {'fluent': [{'code': 'deu', 'name': 'German'},...  Hamburg
# 22   {'fluent': [{'code': 'deu', 'name': 'German'},...  Hamburg
# 23   {'fluent': [{'code': 'eng', 'name': 'English'}...  Hamburg
# 24   {'fluent': [{'code': 'deu', 'name': 'German'},...  Hamburg
# 25   {'fluent': [{'code': 'deu', 'name': 'German'},...  Hamburg
# 26   {'fluent': [{'code': 'nld', 'name': 'Dutch'}, ...  Hamburg
# 27   {'fluent': [{'code': 'eng', 'name': 'English'}...  Hamburg
# 28   {'fluent': [{'code': 'deu', 'name': 'German'},...  Hamburg
# 29   {'fluent': [{'code': 'deu', 'name': 'German'},...  Hamburg
# ..                                                 ...      ...
# 429  {'fluent': [{'code': 'deu', 'name': 'German'},...  Hamburg
# 430  {'fluent': [{'code': 'eng', 'name': 'English'}...  Hamburg
# 431  {'fluent': [{'code': 'deu', 'name': 'German'},...  Hamburg
# 432    {'fluent': [{'code': 'deu', 'name': 'German'}]}  Hamburg
# 433                                     {'fluent': []}  Hamburg
# 434                                     {'fluent': []}  Hamburg
# 435  {'fluent': [{'code': 'deu', 'name': 'German'},...  Hamburg
# 436  {'fluent': [{'code': 'deu', 'name': 'German'},...  Hamburg
# 437   {'fluent': [{'code': 'eng', 'name': 'English'}]}  Hamburg
# 438                                     {'fluent': []}  Hamburg
# 439  {'fluent': [{'code': 'deu', 'name': 'German'},...  Hamburg
# 440    {'fluent': [{'code': 'deu', 'name': 'German'}]}  Hamburg
# 441  {'fluent': [{'code': 'hin', 'name': 'Hindi'}, ...  Hamburg
# 442  {'fluent': [{'code': 'deu', 'name': 'German'},...  Hamburg
# 443  {'fluent': [{'code': 'eng', 'name': 'English'}...  Hamburg
# 444  {'fluent': [{'code': 'deu', 'name': 'German'},...  Hamburg
# 445  {'fluent': [{'code': 'eng', 'name': 'English'}...  Hamburg
# 446  {'fluent': [{'code': 'deu', 'name': 'German'},...  Hamburg
# 447  {'fluent': [{'code': 'deu', 'name': 'German'},...  Hamburg
# 448  {'fluent': [{'code': 'deu', 'name': 'German'},...  Hamburg
# 449   {'fluent': [{'code': 'eng', 'name': 'English'}]}  Hamburg
# 450    {'fluent': [{'code': 'deu', 'name': 'German'}]}  Hamburg
# 451                                     {'fluent': []}  Hamburg
# 452                                     {'fluent': []}  Hamburg
# 453                                     {'fluent': []}  Hamburg
# 454  {'fluent': [{'code': 'deu', 'name': 'German'},...  Hamburg
# 455  {'fluent': [{'code': 'deu', 'name': 'German'},...  Hamburg
# 456                                     {'fluent': []}  Hamburg
# 457  {'fluent': [{'code': 'deu', 'name': 'German'},...  Hamburg
# 458  {'fluent': [{'code': 'eng', 'name': 'English'}...  Hamburg
#
# [459 rows x 15 columns]

# %%
startHost= hosts.index[hosts['id']==2008981650]
startHost.tolist()
# Out:
# [5]

# %%
test = importHosts(index=3)

# %%
test.loc[test['id']==1005431874]
# Out:
#              id   publicName  \
# 346  1005431874  Diana Green
#
#                                              avatarUrl  isVerified status  \
# 346  https://tcdn.couchsurfing.com/r6zzQeAiNPWdywuU...        True  maybe
#
#     lastLogin                                          aboutText  \
# 346    8 days  Aloha couchsurfing crowd!\r\nI've joined couch...
#
#      responseRate                   responseTimeText   responseRateText  \
# 346            53  takes longer than a week to reply  53% response rate
#
#      totalReferencesCount          profileLink  friendsCount  \
# 346                    32  /people/diana_green            26
#
#                                              languages    city
# 346  {'fluent': [{'code': 'deu', 'name': 'German'},...  Berlin

# %%
test.loc[347]
# Out:
# id                                                             2009040605
# publicName                                                    Eva Blanca
# avatarUrl               https://tcdn.couchsurfing.com/exQFrHZcLex40wLY...
# isVerified                                                           True
# status                                                              maybe
# lastLogin                                                          3 days
# aboutText               hi dear Couchsurfer Community \r\nI'm Eva Blan...
# responseRate                                                           -1
# responseTimeText                        takes longer than a week to reply
# responseRateText                                        -1% response rate
# totalReferencesCount                                                    1
# profileLink                                             /users/2009040605
# friendsCount                                                            5
# languages               {'fluent': [{'code': 'spa', 'name': 'Spanish'}...
# city                                                               Berlin
# Name: 347, dtype: object
